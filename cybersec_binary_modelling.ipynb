# %% [markdown]
# # SPRINT 2: Baseline Modelling and Binary Classification
#
# The aim of sprint 2 is to get to sharpen EDA, preprocess data, feature engineering start working with basic models.
#
# After that I will turn to fine tunining the models for the binary classification task: can we indentify cyberattacks reliably?
#
# This notbook is divided in the following sections:
#
# - Load data and optimize it for model training (same as sprint 1)
# - Experiments
# - Fine tuning
#
# My goal here is to find a basic pipeline that raises the performance (with recall metric at 70%) above the research on CICIOT by customizing the models around one kind of attack.

# %% [markdown]
# ## Load data and process it

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ### Extracting the relevant data from csv files
#
#
# Now, we know from previous exploration that we have 34 labels. For EDA purposes we should remap them in 5 kinds:
#
# - Benign Traffic
# - DDoS attacks
# - DoS attacks
# - Mirai attacks
# - Spoofing attacks
# - Web attacks
# - Brute Force attacks
# - Recon attacks
#
# The following table breaks down the categories:
#
# | Attack Category    | Attack Objective                                  | Entry Points                | Expected Network Traffic Change |
# |--------------------|---------------------------------------------------|-----------------------------|---------------------------------|
# | Benign Traffic     | Normal network operations                         | Various                     | No significant change          |
# | DDoS Attacks       | Disrupt service by overwhelming resources         | Network interfaces          | Significant increase           |
# | DoS Attacks        | Disrupt service to a server or network            | Network interfaces          | Sudden spike or drop           |
# | Mirai Attacks      | Exploit IoT devices for large-scale attacks       | IoT devices                 | Varied, often increased        |
# | Spoofing Attacks   | Impersonate devices or users                      | Network interfaces, devices | Varied, potential increase     |
# | Web Attacks        | Exploit web services vulnerabilities              | Web servers, applications   | Varied, often targeted         |
# | Brute Force Attacks| Crack passwords through trial and error          | Authentication systems      | Varied, often increased        |
# | Recon Attacks      | Gather information about network and vulnerabilities | Network scanning, probing | Minor, but patterned increase  |

# %% [markdown]
# We know from the litterature on the dataset that previous modelling attempts were very good at detecting DDoS and DoS attacks.
#
# This is why we focus on Recon attacks.
#
# To do so we have to extract relevant data from the 126 .csv files and create a single data frame.
#
# Let's first take a sample from these:

# %%
# Creating list of csv files 
directory = r"C:\Users\dfuma\Documents\cybersec_cap\data\wataiData\csv\CICIoT2023"
csv_files = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.csv')]

# Taking one sample
sample_df = pd.read_csv(r"C:\Users\dfuma\Documents\cybersec_cap\data\wataiData\csv\CICIoT2023\part-00000-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv")
sample_df.columns
# Out:
# Index(['flow_duration', 'Header_Length', 'Protocol Type', 'Duration', 'Rate',
#        'Srate', 'Drate', 'fin_flag_number', 'syn_flag_number',
#        'rst_flag_number', 'psh_flag_number', 'ack_flag_number',
#        'ece_flag_number', 'cwr_flag_number', 'ack_count', 'syn_count',
#        'fin_count', 'urg_count', 'rst_count', 'HTTP', 'HTTPS', 'DNS', 'Telnet',
#        'SMTP', 'SSH', 'IRC', 'TCP', 'UDP', 'DHCP', 'ARP', 'ICMP', 'IPv', 'LLC',
#        'Tot sum', 'Min', 'Max', 'AVG', 'Std', 'Tot size', 'IAT', 'Number',
#        'Magnitue', 'Radius', 'Covariance', 'Variance', 'Weight', 'label'],
#       dtype='object')

# %% [markdown]
# Now we have to make sure the data types will stay the same while we append each chunk to the combined data frame.

# %%
# Create dictionary with column and data type
d_types = {k: v.name for k, v in zip(sample_df.columns,sample_df.dtypes)}

d_types
# Out:
# {'flow_duration': 'float64',
#  'Header_Length': 'float64',
#  'Protocol Type': 'float64',
#  'Duration': 'float64',
#  'Rate': 'float64',
#  'Srate': 'float64',
#  'Drate': 'float64',
#  'fin_flag_number': 'float64',
#  'syn_flag_number': 'float64',
#  'rst_flag_number': 'float64',
#  'psh_flag_number': 'float64',
#  'ack_flag_number': 'float64',
#  'ece_flag_number': 'float64',
#  'cwr_flag_number': 'float64',
#  'ack_count': 'float64',
#  'syn_count': 'float64',
#  'fin_count': 'float64',
#  'urg_count': 'float64',
#  'rst_count': 'float64',
#  'HTTP': 'float64',
#  'HTTPS': 'float64',
#  'DNS': 'float64',
#  'Telnet': 'float64',
#  'SMTP': 'float64',
#  'SSH': 'float64',
#  'IRC': 'float64',
#  'TCP': 'float64',
#  'UDP': 'float64',
#  'DHCP': 'float64',
#  'ARP': 'float64',
#  'ICMP': 'float64',
#  'IPv': 'float64',
#  'LLC': 'float64',
#  'Tot sum': 'float64',
#  'Min': 'float64',
#  'Max': 'float64',
#  'AVG': 'float64',
#  'Std': 'float64',
#  'Tot size': 'float64',
#  'IAT': 'float64',
#  'Number': 'float64',
#  'Magnitue': 'float64',
#  'Radius': 'float64',
#  'Covariance': 'float64',
#  'Variance': 'float64',
#  'Weight': 'float64',
#  'label': 'object'}

# %% [markdown]
# Now let's use this data type read each csv. Subsequently we will filter on the labels that we need: those whith benign traffic and those with the 5 kinds of recon attacks.

# %%
# Initialize empty df
combined_df = pd.DataFrame()


# List the labels that we need from each csv file
labels_select = ['Recon-PingSweep', 'Recon-OSScan', 'Recon-PortScan', 'VulnerabilityScan', 'Recon-HostDiscovery', 'BenignTraffic']

# Loop over the list of csv file
for file_path in csv_files:
    df = pd.read_csv(file_path, dtype=d_types, low_memory=False) # read the data with d_types

    # Filter based on the selected labels
    filtered_df = df[df['label'].isin(labels_select)]

    # append to combined_df
    combined_df = pd.concat([combined_df, filtered_df], ignore_index=True)

# %%
# Check the result
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1452760 entries, 0 to 1452759
# Data columns (total 47 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   flow_duration    1452760 non-null  float64
#  1   Header_Length    1452760 non-null  float64
#  2   Protocol Type    1452760 non-null  float64
#  3   Duration         1452760 non-null  float64
#  4   Rate             1452760 non-null  float64
#  5   Srate            1452760 non-null  float64
#  6   Drate            1452760 non-null  float64
#  7   fin_flag_number  1452760 non-null  float64
#  8   syn_flag_number  1452760 non-null  float64
#  9   rst_flag_number  1452760 non-null  float64
#  10  psh_flag_number  1452760 non-null  float64
#  11  ack_flag_number  1452760 non-null  float64
#  12  ece_flag_number  1452760 non-null  float64
#  13  cwr_flag_number  1452760 non-null  float64
#  14  ack_count        1452760 non-null  float64
#  15  syn_count        1452760 non-null  float64
#  16  fin_count        1452760 non-null  float64
#  17  urg_count        1452760 non-null  float64
#  18  rst_count        1452760 non-null  float64
#  19  HTTP             1452760 non-null  float64
#  20  HTTPS            1452760 non-null  float64
#  21  DNS              1452760 non-null  float64
#  22  Telnet           1452760 non-null  float64
#  23  SMTP             1452760 non-null  float64
#  24  SSH              1452760 non-null  float64
#  25  IRC              1452760 non-null  float64
#  26  TCP              1452760 non-null  float64
#  27  UDP              1452760 non-null  float64
#  28  DHCP             1452760 non-null  float64
#  29  ARP              1452760 non-null  float64
#  30  ICMP             1452760 non-null  float64
#  31  IPv              1452760 non-null  float64
#  32  LLC              1452760 non-null  float64
#  33  Tot sum          1452760 non-null  float64
#  34  Min              1452760 non-null  float64
#  35  Max              1452760 non-null  float64
#  36  AVG              1452760 non-null  float64
#  37  Std              1452760 non-null  float64
#  38  Tot size         1452760 non-null  float64
#  39  IAT              1452760 non-null  float64
#  40  Number           1452760 non-null  float64
#  41  Magnitue         1452760 non-null  float64
#  42  Radius           1452760 non-null  float64
#  43  Covariance       1452760 non-null  float64
#  44  Variance         1452760 non-null  float64
#  45  Weight           1452760 non-null  float64
#  46  label            1452760 non-null  object
# dtypes: float64(46), object(1)
# memory usage: 520.9+ MB

# %%
# Check shape
combined_df.shape[0]
# Out:
# 1452760

# %%
# Check NAs, we expect 0
combined_df.isna().sum()
# Out:
# flow_duration      0
# Header_Length      0
# Protocol Type      0
# Duration           0
# Rate               0
# Srate              0
# Drate              0
# fin_flag_number    0
# syn_flag_number    0
# rst_flag_number    0
# psh_flag_number    0
# ack_flag_number    0
# ece_flag_number    0
# cwr_flag_number    0
# ack_count          0
# syn_count          0
# fin_count          0
# urg_count          0
# rst_count          0
# HTTP               0
# HTTPS              0
# DNS                0
# Telnet             0
# SMTP               0
# SSH                0
# IRC                0
# TCP                0
# UDP                0
# DHCP               0
# ARP                0
# ICMP               0
# IPv                0
# LLC                0
# Tot sum            0
# Min                0
# Max                0
# AVG                0
# Std                0
# Tot size           0
# IAT                0
# Number             0
# Magnitue           0
# Radius             0
# Covariance         0
# Variance           0
# Weight             0
# label              0
# dtype: int64

# %%
# Check for duplicates (we expect very few)
combined_df.duplicated().sum()
# Out:
# 5

# %%
# Remove duplicates: df
df = combined_df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (1452755, 47)

# %%
# Clear memory
del combined_df
del sample_df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1452755 entries, 0 to 1452759
# Data columns (total 47 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   flow_duration    1452755 non-null  float64
#  1   Header_Length    1452755 non-null  float64
#  2   Protocol Type    1452755 non-null  float64
#  3   Duration         1452755 non-null  float64
#  4   Rate             1452755 non-null  float64
#  5   Srate            1452755 non-null  float64
#  6   Drate            1452755 non-null  float64
#  7   fin_flag_number  1452755 non-null  float64
#  8   syn_flag_number  1452755 non-null  float64
#  9   rst_flag_number  1452755 non-null  float64
#  10  psh_flag_number  1452755 non-null  float64
#  11  ack_flag_number  1452755 non-null  float64
#  12  ece_flag_number  1452755 non-null  float64
#  13  cwr_flag_number  1452755 non-null  float64
#  14  ack_count        1452755 non-null  float64
#  15  syn_count        1452755 non-null  float64
#  16  fin_count        1452755 non-null  float64
#  17  urg_count        1452755 non-null  float64
#  18  rst_count        1452755 non-null  float64
#  19  HTTP             1452755 non-null  float64
#  20  HTTPS            1452755 non-null  float64
#  21  DNS              1452755 non-null  float64
#  22  Telnet           1452755 non-null  float64
#  23  SMTP             1452755 non-null  float64
#  24  SSH              1452755 non-null  float64
#  25  IRC              1452755 non-null  float64
#  26  TCP              1452755 non-null  float64
#  27  UDP              1452755 non-null  float64
#  28  DHCP             1452755 non-null  float64
#  29  ARP              1452755 non-null  float64
#  30  ICMP             1452755 non-null  float64
#  31  IPv              1452755 non-null  float64
#  32  LLC              1452755 non-null  float64
#  33  Tot sum          1452755 non-null  float64
#  34  Min              1452755 non-null  float64
#  35  Max              1452755 non-null  float64
#  36  AVG              1452755 non-null  float64
#  37  Std              1452755 non-null  float64
#  38  Tot size         1452755 non-null  float64
#  39  IAT              1452755 non-null  float64
#  40  Number           1452755 non-null  float64
#  41  Magnitue         1452755 non-null  float64
#  42  Radius           1452755 non-null  float64
#  43  Covariance       1452755 non-null  float64
#  44  Variance         1452755 non-null  float64
#  45  Weight           1452755 non-null  float64
#  46  label            1452755 non-null  object
# dtypes: float64(46), object(1)
# memory usage: 532.0+ MB

# %% [markdown]
# Now let's change the data types for better efficiency

# %%
dtypes = {
        'flow_duration': np.float32,
        'Header_Length': np.uint32,
        'Protocol Type': str,
        'Duration': np.float32,
        'Rate': np.uint32,
        'Srate': np.uint32,
        'Drate': np.float32,
        'fin_flag_number': np.bool_,
        'syn_flag_number': np.bool_,
        'rst_flag_number': np.bool_,
        'psh_flag_number': np.bool_,
        'ack_flag_number': np.bool_,
        'ece_flag_number': np.bool_,
        'cwr_flag_number': np.bool_,
        'ack_count': np.float16,
        'syn_count': np.float16,
        'fin_count': np.uint16,
        'urg_count': np.uint16, 
        'rst_count': np.uint16, 
        'HTTP': np.bool_, 
        'HTTPS': np.bool_, 
        'DNS': np.bool_, 
        'Telnet': np.bool_,
        'SMTP': np.bool_, 
        'SSH': np.bool_, 
        'IRC': np.bool_, 
        'TCP': np.bool_, 
        'UDP': np.bool_, 
        'DHCP': np.bool_, 
        'ARP': np.bool_, 
        'ICMP': np.bool_, 
        'IPv': np.bool_, 
        'LLC': np.bool_,
        'Tot sum': np.float32, 
        'Min': np.float32, 
        'Max': np.float32, 
        'AVG': np.float32, 
        'Std': np.float32, 
        'Tot size': np.float32, 
        'IAT': np.float32, 
        'Number': np.float32,
        'Magnitue': np.float32, 
        'Radius': np.float32, 
        'Covariance': np.float32, 
        'Variance': np.float32, 
        'Weight': np.float32, 
        'label': str
    }

# Define function to change data type and adjust formatting

def convert_dtype(df):
    # Adjust data type
    for col,typ in dtypes.items():
        df[col] = df[col].astype(typ)   
    
    # Format column names to lowercase snake
    df.columns = df.columns.str.lower().str.replace(' ', '_')
    
    # Fix spelling error in original dataset
    df['magnitude'] = df['magnitue']
    return df.drop(['magnitue'], axis=1)


# call the function
convert_dtype(df)
# Out:
#          flow_duration  header_length protocol_type    duration   rate  srate  \
# 0            37.887028        1687747           9.3   63.500000     34     34
# 1            48.272385         128041          10.4   97.800003  39966  39966
# 2            48.095661         101026           8.8  137.699997     13     13
# 3            46.342407        1301464           4.8  168.300003     34     34
# 4            88.807747        5290348           7.1   63.599998     61     61
# ...                ...            ...           ...         ...    ...    ...
# 1452755       0.732928        2250732           6.0   93.500000   2782   2782
# 1452756      13.401717          11497           6.0   59.200001     11     11
# 1452757       9.528511         116067          12.6   82.699997     17     17
# 1452758      16.250675          85094           8.8  103.400002     15     15
# 1452759      23.311707          47252          10.4   99.199997    108    108
#
#          drate  fin_flag_number  syn_flag_number  rst_flag_number  ...  \
# 0          0.0            False            False            False  ...
# 1          0.0            False            False            False  ...
# 2          0.0            False            False            False  ...
# 3          0.0            False            False            False  ...
# 4          0.0            False            False            False  ...
# ...        ...              ...              ...              ...  ...
# 1452755    0.0            False            False            False  ...
# 1452756    0.0            False            False            False  ...
# 1452757    0.0            False            False            False  ...
# 1452758    0.0            False            False            False  ...
# 1452759    0.0            False            False            False  ...
#
#                  std     tot_size           iat  number       radius  \
# 0         332.122437   817.500000  5.235219e-03     5.5   469.692078
# 1         694.907043   636.400024  1.665200e+08    13.5   983.968323
# 2        1302.117188   919.299988  2.724581e-02     5.5  1841.471802
# 3           0.428562    64.800003  3.804951e-02     5.5     0.606078
# 4         101.938538  1227.300049  1.833391e-03     5.5   144.162857
# ...              ...          ...           ...     ...          ...
# 1452755   836.076416   917.599976  8.809566e-05     5.5  1182.390625
# 1452756    64.519730   108.199997  9.288311e-03     5.5    91.244675
# 1452757   187.924698   337.500000  1.846900e-02     5.5   265.765656
# 1452758   857.873474   105.800003  1.665168e+08    13.5  1215.209839
# 1452759    57.363495   100.500000  1.308570e-02     5.5    81.124229
#
#            covariance  variance      weight          label  magnitude
# 0        2.092362e+05       0.9   38.500000  BenignTraffic  24.333355
# 1        4.842123e+05       1.0  244.600006  BenignTraffic  36.393288
# 2        2.063959e+06       0.9   38.500000  BenignTraffic  47.214172
# 3        9.315556e-01       0.2   38.500000  BenignTraffic  11.472816
# 4        5.276998e+04       0.2   38.500000  BenignTraffic  54.184532
# ...               ...       ...         ...            ...        ...
# 1452755  8.859554e+05       0.8   38.500000  BenignTraffic  38.208549
# 1452756  4.696484e+03       0.9   38.500000  BenignTraffic  14.697835
# 1452757  6.190794e+04       0.9   38.500000  BenignTraffic  19.810381
# 1452758  7.409860e+05       1.0  244.600006  BenignTraffic  34.988182
# 1452759  3.704945e+03       0.9   38.500000  BenignTraffic  14.255463
#
# [1452755 rows x 47 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1452755 entries, 0 to 1452759
# Data columns (total 48 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   flow_duration    1452755 non-null  float32
#  1   header_length    1452755 non-null  uint32
#  2   protocol_type    1452755 non-null  object
#  3   duration         1452755 non-null  float32
#  4   rate             1452755 non-null  uint32
#  5   srate            1452755 non-null  uint32
#  6   drate            1452755 non-null  float32
#  7   fin_flag_number  1452755 non-null  bool
#  8   syn_flag_number  1452755 non-null  bool
#  9   rst_flag_number  1452755 non-null  bool
#  10  psh_flag_number  1452755 non-null  bool
#  11  ack_flag_number  1452755 non-null  bool
#  12  ece_flag_number  1452755 non-null  bool
#  13  cwr_flag_number  1452755 non-null  bool
#  14  ack_count        1452755 non-null  float16
#  15  syn_count        1452755 non-null  float16
#  16  fin_count        1452755 non-null  uint16
#  17  urg_count        1452755 non-null  uint16
#  18  rst_count        1452755 non-null  uint16
#  19  http             1452755 non-null  bool
#  20  https            1452755 non-null  bool
#  21  dns              1452755 non-null  bool
#  22  telnet           1452755 non-null  bool
#  23  smtp             1452755 non-null  bool
#  24  ssh              1452755 non-null  bool
#  25  irc              1452755 non-null  bool
#  26  tcp              1452755 non-null  bool
#  27  udp              1452755 non-null  bool
#  28  dhcp             1452755 non-null  bool
#  29  arp              1452755 non-null  bool
#  30  icmp             1452755 non-null  bool
#  31  ipv              1452755 non-null  bool
#  32  llc              1452755 non-null  bool
#  33  tot_sum          1452755 non-null  float32
#  34  min              1452755 non-null  float32
#  35  max              1452755 non-null  float32
#  36  avg              1452755 non-null  float32
#  37  std              1452755 non-null  float32
#  38  tot_size         1452755 non-null  float32
#  39  iat              1452755 non-null  float32
#  40  number           1452755 non-null  float32
#  41  magnitue         1452755 non-null  float32
#  42  radius           1452755 non-null  float32
#  43  covariance       1452755 non-null  float32
#  44  variance         1452755 non-null  float32
#  45  weight           1452755 non-null  float32
#  46  label            1452755 non-null  object
#  47  magnitude        1452755 non-null  float32
# dtypes: bool(21), float16(2), float32(17), object(2), uint16(3), uint32(3)
# memory usage: 187.0+ MB

# %% [markdown]
# In order to perform EDA we need change protocol types in a format that is human readable. Right now they are a float indicating the protocol type. We will turn that into an integer and apply a mapping with the description of the protocol type using IANA (Internet Assigned Numbers Authority) protocol numbers.

# %%
# Map IANA Protocol numbers to strings (leave user option to 1-hot or numerically encode)
iana_map = { 
    "0": "HOPOPT", "1": "ICMP", "2": "IGMP", "3": "GGP", "4": "IPv4", "5": "ST", 
    "6": "TCP", "7": "CBT", "8": "EGP", "9": "IGP", "10": "BBN-RCC-MON", "11": "NVP-II", 
    "12": "PUP", "13": "ARGUS (deprecated)", "14": "EMCON", "15": "XNET", "16": "CHAOS", 
    "17": "UDP", "18": "MUX", "19": "DCN-MEAS", "20": "HMP", "21": "PRM", "22": "XNS-IDP", 
    "23": "TRUNK-1", "24": "TRUNK-2", "25": "LEAF-1", "26": "LEAF-2", "27": "RDP", 
    "28": "IRTP", "29": "ISO-TP4", "30": "NETBLT", "31": "MFE-NSP", "32": "MERIT-INP", 
    "33": "DCCP", "34": "3PC", "35": "IDPR", "36": "XTP", "37": "DDP", "38": "IDPR-CMTP", 
    "39": "TP++", "40": "IL", "41": "IPv6", "42": "SDRP", "43": "IPv6-Route", 
    "44": "IPv6-Frag", "45": "IDRP", "46": "RSVP", "47": "GRE", "48": "DSR", "49": "BNA", 
    "50": "ESP", "51": "AH", "52": "I-NLSP", "53": "SWIPE (deprecated)", "54": "NARP", 
    "55": "MOBILE", "56": "TLSP", "57": "SKIP", "58": "IPv6-ICMP", "59": "IPv6-NoNxt", 
    "60": "IPv6-Opts", "62": "CFTP", "64": "SAT-EXPAK", "65": "KRYPTOLAN", "66": "RVD", 
    "67": "IPPC", "69": "SAT-MON", "70": "VISA", "71": "IPCV", "72": "CPNX", "73": "CPHB", 
    "74": "WSN", "75": "PVP", "76": "BR-SAT-MON", "77": "SUN-ND", "78": "WB-MON", 
    "79": "WB-EXPAK", "80": "ISO-IP", "81": "VMTP", "82": "SECURE-VMTP", "83": "VINES", 
    "84": "IPTM", "85": "NSFNET-IGP", "86": "DGP", "87": "TCF", "88": "EIGRP", 
    "89": "OSPFIGP", "90": "Sprite-RPC", "91": "LARP", "92": "MTP", "93": "AX.25", 
    "94": "IPIP", "95": "MICP (deprecated)","96": "SCC-SP", "97": "ETHERIP", "98": "ENCAP", 
    "100": "GMTP", "101": "IFMP", "102": "PNNI", "103": "PIM", "104": "ARIS", "105": "SCPS", 
    "106": "QNX", "107": "A/N", "108": "IPComp", "109": "SNP", "110": "Compaq-Peer", 
    "111": "IPX-in-IP", "112": "VRRP", "113": "PGM", "114": "", "115": "L2TP", "116": "DDX",  
    "117": "IATP", "118": "STP", "119": "SRP", "120": "UTI", "121": "SMP", 
    "122": "SM (deprecated)", "123": "PTP","124": "ISIS over IPv4", "125": "FIRE", 
    "126": "CRTP", "127": "CRUDP", "128": "SSCOPMCE", "129": "IPLT", "130": "SPS", 
    "131": "PIPE", "132": "SCTP",  "133": "FC", "134": "RSVP-E2E-IGNORE", 
    "135": "Mobility Header", "136": "UDPLite", "137": "MPLS-in-IP", "138": "manet", 
    "139": "HIP", "140": "Shim6", "141": "WESP", "142": "ROHC", "143": "Ethernet", 
    "144": "AGGFRAG", "145": "NSH"
}

# transform the column protocol type

df['protocol_type'] = df['protocol_type'].apply(lambda x: iana_map[str(int(float(x)))])

set(df['protocol_type'])
# Out:
# {'ARGUS (deprecated)',
#  'BBN-RCC-MON',
#  'CBT',
#  'CHAOS',
#  'EGP',
#  'EMCON',
#  'GGP',
#  'HOPOPT',
#  'ICMP',
#  'IGMP',
#  'IGP',
#  'IPv4',
#  'NVP-II',
#  'PUP',
#  'ST',
#  'TCP',
#  'UDP',
#  'XNET'}

# %% [markdown]
# Since we are still dealing with Binary Classification proglem, I will create a target feature that groups all Recon Attacks into one category: 'ReconAttack'.

# %%
def is_recon(x):
    if x == 'BenignTraffic':
        return 'BenignTraffic'
    else:
        return 'ReconAttack'

df['label_red'] = df['label'].map(is_recon)

# %% [markdown]
# Check the column's content.

# %%
set(df['label_red'])
# Out:
# {'BenignTraffic', 'ReconAttack'}

# %% [markdown]
# Let's also hot-encode the target feature.

# %%
# Hot encoded label_red
df['label_red_bin'] = df['label_red'].map({'BenignTraffic': 0, 'ReconAttack': 1})
df['label_red_bin'].value_counts()
# Out:
# label_red_bin
# 0    1098195
# 1     354560
# Name: count, dtype: int64

# %% [markdown]
# Now let's create dummies for protocol type as they could be useful for the models as EDA showed.

# %%
df = pd.get_dummies(df, columns=['protocol_type'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1452755 entries, 0 to 1452759
# Data columns (total 67 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   flow_duration                     1452755 non-null  float32
#  1   header_length                     1452755 non-null  uint32
#  2   duration                          1452755 non-null  float32
#  3   rate                              1452755 non-null  uint32
#  4   srate                             1452755 non-null  uint32
#  5   drate                             1452755 non-null  float32
#  6   fin_flag_number                   1452755 non-null  bool
#  7   syn_flag_number                   1452755 non-null  bool
#  8   rst_flag_number                   1452755 non-null  bool
#  9   psh_flag_number                   1452755 non-null  bool
#  10  ack_flag_number                   1452755 non-null  bool
#  11  ece_flag_number                   1452755 non-null  bool
#  12  cwr_flag_number                   1452755 non-null  bool
#  13  ack_count                         1452755 non-null  float16
#  14  syn_count                         1452755 non-null  float16
#  15  fin_count                         1452755 non-null  uint16
#  16  urg_count                         1452755 non-null  uint16
#  17  rst_count                         1452755 non-null  uint16
#  18  http                              1452755 non-null  bool
#  19  https                             1452755 non-null  bool
#  20  dns                               1452755 non-null  bool
#  21  telnet                            1452755 non-null  bool
#  22  smtp                              1452755 non-null  bool
#  23  ssh                               1452755 non-null  bool
#  24  irc                               1452755 non-null  bool
#  25  tcp                               1452755 non-null  bool
#  26  udp                               1452755 non-null  bool
#  27  dhcp                              1452755 non-null  bool
#  28  arp                               1452755 non-null  bool
#  29  icmp                              1452755 non-null  bool
#  30  ipv                               1452755 non-null  bool
#  31  llc                               1452755 non-null  bool
#  32  tot_sum                           1452755 non-null  float32
#  33  min                               1452755 non-null  float32
#  34  max                               1452755 non-null  float32
#  35  avg                               1452755 non-null  float32
#  36  std                               1452755 non-null  float32
#  37  tot_size                          1452755 non-null  float32
#  38  iat                               1452755 non-null  float32
#  39  number                            1452755 non-null  float32
#  40  magnitue                          1452755 non-null  float32
#  41  radius                            1452755 non-null  float32
#  42  covariance                        1452755 non-null  float32
#  43  variance                          1452755 non-null  float32
#  44  weight                            1452755 non-null  float32
#  45  label                             1452755 non-null  object
#  46  magnitude                         1452755 non-null  float32
#  47  label_red                         1452755 non-null  object
#  48  label_red_bin                     1452755 non-null  int64
#  49  protocol_type_ARGUS (deprecated)  1452755 non-null  bool
#  50  protocol_type_BBN-RCC-MON         1452755 non-null  bool
#  51  protocol_type_CBT                 1452755 non-null  bool
#  52  protocol_type_CHAOS               1452755 non-null  bool
#  53  protocol_type_EGP                 1452755 non-null  bool
#  54  protocol_type_EMCON               1452755 non-null  bool
#  55  protocol_type_GGP                 1452755 non-null  bool
#  56  protocol_type_HOPOPT              1452755 non-null  bool
#  57  protocol_type_ICMP                1452755 non-null  bool
#  58  protocol_type_IGMP                1452755 non-null  bool
#  59  protocol_type_IGP                 1452755 non-null  bool
#  60  protocol_type_IPv4                1452755 non-null  bool
#  61  protocol_type_NVP-II              1452755 non-null  bool
#  62  protocol_type_PUP                 1452755 non-null  bool
#  63  protocol_type_ST                  1452755 non-null  bool
#  64  protocol_type_TCP                 1452755 non-null  bool
#  65  protocol_type_UDP                 1452755 non-null  bool
#  66  protocol_type_XNET                1452755 non-null  bool
# dtypes: bool(39), float16(2), float32(17), int64(1), object(2), uint16(3), uint32(3)
# memory usage: 223.1+ MB

# %%
# select numerical columns

df_numerical = df.select_dtypes(include=['bool','uint16','uint32','int64','float16','float32'])

# %% [markdown]
# ### Final Checks
#
# here I want to make sure we are really ready for modelling. It's crucial step: tide up your dataset or be sorry later!

# %%
df_numerical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1452755 entries, 0 to 1452759
# Data columns (total 65 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   flow_duration                     1452755 non-null  float32
#  1   header_length                     1452755 non-null  uint32
#  2   duration                          1452755 non-null  float32
#  3   rate                              1452755 non-null  uint32
#  4   srate                             1452755 non-null  uint32
#  5   drate                             1452755 non-null  float32
#  6   fin_flag_number                   1452755 non-null  bool
#  7   syn_flag_number                   1452755 non-null  bool
#  8   rst_flag_number                   1452755 non-null  bool
#  9   psh_flag_number                   1452755 non-null  bool
#  10  ack_flag_number                   1452755 non-null  bool
#  11  ece_flag_number                   1452755 non-null  bool
#  12  cwr_flag_number                   1452755 non-null  bool
#  13  ack_count                         1452755 non-null  float16
#  14  syn_count                         1452755 non-null  float16
#  15  fin_count                         1452755 non-null  uint16
#  16  urg_count                         1452755 non-null  uint16
#  17  rst_count                         1452755 non-null  uint16
#  18  http                              1452755 non-null  bool
#  19  https                             1452755 non-null  bool
#  20  dns                               1452755 non-null  bool
#  21  telnet                            1452755 non-null  bool
#  22  smtp                              1452755 non-null  bool
#  23  ssh                               1452755 non-null  bool
#  24  irc                               1452755 non-null  bool
#  25  tcp                               1452755 non-null  bool
#  26  udp                               1452755 non-null  bool
#  27  dhcp                              1452755 non-null  bool
#  28  arp                               1452755 non-null  bool
#  29  icmp                              1452755 non-null  bool
#  30  ipv                               1452755 non-null  bool
#  31  llc                               1452755 non-null  bool
#  32  tot_sum                           1452755 non-null  float32
#  33  min                               1452755 non-null  float32
#  34  max                               1452755 non-null  float32
#  35  avg                               1452755 non-null  float32
#  36  std                               1452755 non-null  float32
#  37  tot_size                          1452755 non-null  float32
#  38  iat                               1452755 non-null  float32
#  39  number                            1452755 non-null  float32
#  40  magnitue                          1452755 non-null  float32
#  41  radius                            1452755 non-null  float32
#  42  covariance                        1452755 non-null  float32
#  43  variance                          1452755 non-null  float32
#  44  weight                            1452755 non-null  float32
#  45  magnitude                         1452755 non-null  float32
#  46  label_red_bin                     1452755 non-null  int64
#  47  protocol_type_ARGUS (deprecated)  1452755 non-null  bool
#  48  protocol_type_BBN-RCC-MON         1452755 non-null  bool
#  49  protocol_type_CBT                 1452755 non-null  bool
#  50  protocol_type_CHAOS               1452755 non-null  bool
#  51  protocol_type_EGP                 1452755 non-null  bool
#  52  protocol_type_EMCON               1452755 non-null  bool
#  53  protocol_type_GGP                 1452755 non-null  bool
#  54  protocol_type_HOPOPT              1452755 non-null  bool
#  55  protocol_type_ICMP                1452755 non-null  bool
#  56  protocol_type_IGMP                1452755 non-null  bool
#  57  protocol_type_IGP                 1452755 non-null  bool
#  58  protocol_type_IPv4                1452755 non-null  bool
#  59  protocol_type_NVP-II              1452755 non-null  bool
#  60  protocol_type_PUP                 1452755 non-null  bool
#  61  protocol_type_ST                  1452755 non-null  bool
#  62  protocol_type_TCP                 1452755 non-null  bool
#  63  protocol_type_UDP                 1452755 non-null  bool
#  64  protocol_type_XNET                1452755 non-null  bool
# dtypes: bool(39), float16(2), float32(17), int64(1), uint16(3), uint32(3)
# memory usage: 200.9 MB

# %% [markdown]
# We need the full memory at work! let's delete the memory

# %%
#df.to_csv('cybersec_reworked.csv', index=False)
del df

# %% [markdown]
# Check again d_types

# %%
d_types = {k: v.name for k, v in zip(df_numerical.columns,df_numerical.dtypes)}

d_types
# Out:
# {'flow_duration': 'float32',
#  'header_length': 'uint32',
#  'duration': 'float32',
#  'rate': 'uint32',
#  'srate': 'uint32',
#  'drate': 'float32',
#  'fin_flag_number': 'bool',
#  'syn_flag_number': 'bool',
#  'rst_flag_number': 'bool',
#  'psh_flag_number': 'bool',
#  'ack_flag_number': 'bool',
#  'ece_flag_number': 'bool',
#  'cwr_flag_number': 'bool',
#  'ack_count': 'float16',
#  'syn_count': 'float16',
#  'fin_count': 'uint16',
#  'urg_count': 'uint16',
#  'rst_count': 'uint16',
#  'http': 'bool',
#  'https': 'bool',
#  'dns': 'bool',
#  'telnet': 'bool',
#  'smtp': 'bool',
#  'ssh': 'bool',
#  'irc': 'bool',
#  'tcp': 'bool',
#  'udp': 'bool',
#  'dhcp': 'bool',
#  'arp': 'bool',
#  'icmp': 'bool',
#  'ipv': 'bool',
#  'llc': 'bool',
#  'tot_sum': 'float32',
#  'min': 'float32',
#  'max': 'float32',
#  'avg': 'float32',
#  'std': 'float32',
#  'tot_size': 'float32',
#  'iat': 'float32',
#  'number': 'float32',
#  'magnitue': 'float32',
#  'radius': 'float32',
#  'covariance': 'float32',
#  'variance': 'float32',
#  'weight': 'float32',
#  'magnitude': 'float32',
#  'label_red_bin': 'int64',
#  'protocol_type_ARGUS (deprecated)': 'bool',
#  'protocol_type_BBN-RCC-MON': 'bool',
#  'protocol_type_CBT': 'bool',
#  'protocol_type_CHAOS': 'bool',
#  'protocol_type_EGP': 'bool',
#  'protocol_type_EMCON': 'bool',
#  'protocol_type_GGP': 'bool',
#  'protocol_type_HOPOPT': 'bool',
#  'protocol_type_ICMP': 'bool',
#  'protocol_type_IGMP': 'bool',
#  'protocol_type_IGP': 'bool',
#  'protocol_type_IPv4': 'bool',
#  'protocol_type_NVP-II': 'bool',
#  'protocol_type_PUP': 'bool',
#  'protocol_type_ST': 'bool',
#  'protocol_type_TCP': 'bool',
#  'protocol_type_UDP': 'bool',
#  'protocol_type_XNET': 'bool'}

# %% [markdown]
# Ok now we can use df_numerical and save it with integers vs boolean to ensure data type consistency across platforms (say on google colab)

# %%
# Convert boolean columns to integers
bool_cols = df_numerical.select_dtypes(include=['bool']).columns
df_numerical[bool_cols] = df_numerical[bool_cols].astype(int) # CONVERTING TO INTEGERS IN ORDER TO AVOID CORRUPTION

# Save to CSV
#df_numerical.to_csv('df_numerical_modified.csv', index=False)

# THIS WAS SENT TO GOOGLE COLAB for parallel model training.

# %% [markdown]
# Another check is on the right-skewness of the data. I would like to identify the columns that for regression-based models would maybe need further transformation.

# %%
# Set the style of seaborn for better visuals
sns.set(style="whitegrid")

# Plotting histograms for each column
for column in df_numerical.columns:
    plt.figure(figsize=(3, 3))
    if df_numerical[column].dtype in ['float64', 'int64']:  # Check if the column is numeric
        sns.histplot(df_numerical[column], kde=True, bins=30)  # Adjust bins as needed
        plt.title(f'Histogram of {column}')
        plt.xlabel(column)
        plt.ylabel('Frequency')
        plt.show()
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_2692\1779241437.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(3, 3))

# %%
for c in df_numerical.iloc[:, 46:64].columns:
    print(str(df_numerical[c].name) + " : " + str(set(df_numerical[c])))
# Out:
# label_red_bin : {0, 1}
# protocol_type_ARGUS (deprecated) : {0, 1}
# protocol_type_BBN-RCC-MON : {0, 1}
# protocol_type_CBT : {0, 1}
# protocol_type_CHAOS : {0, 1}
# protocol_type_EGP : {0, 1}
# protocol_type_EMCON : {0, 1}
# protocol_type_GGP : {0, 1}
# protocol_type_HOPOPT : {0, 1}
# protocol_type_ICMP : {0, 1}
# protocol_type_IGMP : {0, 1}
# protocol_type_IGP : {0, 1}
# protocol_type_IPv4 : {0, 1}
# protocol_type_NVP-II : {0, 1}
# protocol_type_PUP : {0, 1}
# protocol_type_ST : {0, 1}
# protocol_type_TCP : {0, 1}
# protocol_type_UDP : {0, 1}

# %% [markdown]
# ## Baseline modelling Experiments
#
# For baseline modelling we have three main objectives:
#
# - how sensible is the performance of the models to dimensionality reduction?
# - which method is best for treating class imbalance?
# - do linear models perform as well as non-linear ones?
#
# As a byproduct of formulating and testing these hypotheses we will also get some precious feedback on how much computing time the different options will take.
#
# The following cells will be all about formulating hypothesis and get some results from them.
# At this stage is really about exploration so I don't want to  constrict myself on any particular pre-enstablished process.

# %% [markdown]
# ### Experiment 1: downsample-reduce-evaluate
#
# Our dataset is a big one: 1.5 million rows for 67 columns.
#
# This means that even the simplest models will take a long time to run, with my machine (which for CPU tasks is faster than google colab) it will take houndreds of minutes.
#
# Another characteristic is that if we treat this problem as a binary classification (benign traffic vs recon attack) we have class imbalance with the minority being 24% of the dataset.
#
# Maybe we can treat the two problems at the same time this way:
#
# - Use a combination of SMOTE and RandomUndersample to reduce the size of the data and balance the minority class
# - Scale the data
# - Use PCA to reduce the number of components, say at 25
# - Compare with different regularization a linear classifier (Logistic Regression) to a non linear one (SVM with kernel rbf)
# - Test to the original data (we will need to scale using the resampled scaler)
#
# to do this we'll be combining a Pipeline with GridSearchCV optimized for recall.
#
# Why recall? We are interested in detecting the cyberattack most of all! We have a recall value for Recon activities in the original research of 70% (in a 5 class classification).
# My idea is that by focusing only on one particular kind of attack we'll have better results.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


X = df_numerical.drop(columns=['label_red_bin'])

y = df_numerical['label_red_bin']

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=33, test_size=0.3)

# %%
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Define SMOTE and Random Undersampling steps
over = SMOTE(sampling_strategy=0.5)  # Minority class becomes 50% of majority
under = RandomUnderSampler(sampling_strategy=0.6)  # Overall size becomes 30% of original

'''

# Define the pipeline
pipeline = ImbPipeline([
    ('over', over),
    ('under', under),
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=25)),
    ('clf', LogisticRegression(n_jobs=-1))  # Placeholder, will be tuned by GridSearchCV
])

# Parameter grid
param_grid = {
    'clf': [LogisticRegression(n_jobs=-1), SVC(kernel='rbf')],
    'clf__C': [0.1, 1, 10]  # Common C values for both LogisticRegression and SVC
}

# Configure GridSearchCV
grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='recall', verbose=1)

# Fit GridSearchCV
grid_search.fit(X_train, y_train)

# Transform X_test using the pipeline
X_test_transformed = grid_search.best_estimator_.named_steps['scaler'].transform(X_test)

# Evaluate the best model on the original X_test and y_test
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test_transformed)
print(classification_report(y_test, y_pred)) 

'''
# Out:
# "\n\n# Define the pipeline\npipeline = ImbPipeline([\n    ('over', over),\n    ('under', under),\n    ('scaler', StandardScaler()),\n    ('pca', PCA(n_components=25)),\n    ('clf', LogisticRegression(n_jobs=-1))  # Placeholder, will be tuned by GridSearchCV\n])\n\n# Parameter grid\nparam_grid = {\n    'clf': [LogisticRegression(n_jobs=-1), SVC(kernel='rbf')],\n    'clf__C': [0.1, 1, 10]  # Common C values for both LogisticRegression and SVC\n}\n\n# Configure GridSearchCV\ngrid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='recall', verbose=1)\n\n# Fit GridSearchCV\ngrid_search.fit(X_train, y_train)\n\n# Transform X_test using the pipeline\nX_test_transformed = grid_search.best_estimator_.named_steps['scaler'].transform(X_test)\n\n# Evaluate the best model on the original X_test and y_test\nbest_model = grid_search.best_estimator_\ny_pred = best_model.predict(X_test_transformed)\nprint(classification_report(y_test, y_pred)) \n\n"

# %% [markdown]
# Unfortunately, we could not run this gridsearchcv as after 33 hours the model was still running.
#
# I will try again with a better computing infrastructure
#
# Conclusion: we need to be careful when working this dataset, we just cannot "gridsearchcv our way out of it"!

# %% [markdown]
# ### Experiment 2: how does PCA impact?
#
# We need to understand what's the cost of PCA. In other words: what is the relationship between each component and the variance?
#
# Let's find out by running a PCA and plot the cumulative explained variance for each component.

# %%
scaler = StandardScaler().fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.decomposition import PCA


my_PCA = PCA()
my_PCA.fit(X_train_scaled)

# transform data 
X_train_PCA = my_PCA.transform(X_train_scaled)
X_test_PCA = my_PCA.transform(X_test_scaled)

# %%
expl_var = my_PCA.explained_variance_ratio_
cumulative_sum = np.cumsum(expl_var) #TODO check this one
cumsum_range = np.arange(0, len(cumulative_sum))

# Plot out the cumulative sum graph

plt.figure()
plt.plot(cumsum_range, cumulative_sum, marker='.')
plt.axhline(0.9, c='r', linestyle='--')
plt.xlabel('Number of PCs')
plt.ylabel('Cumulative Sum of Explained Variance')

plt.show()

# %% [markdown]
#  There appears to be an 'elbow' in the plot, which is the point where the rate of increase in explained variance drops significantly. This point is often used to select a reasonable number of components in PCA.
#
#  That's a little bit of a problem: with the elbow starting at variance 0.5 cumulative variance explained.
#
#  Let's see if another form of decomposition works better: Truncated SVD.
#
#  Why Truncated SVD? Beacuse it ususally works better than PCA in sparse matixes. We have a considerable amount of dummy variables mostly 0. Maybe is good in our case.

# %%
from sklearn.decomposition import TruncatedSVD


my_tr_svd = TruncatedSVD(n_components=len(X.columns))
my_tr_svd.fit(X_train_scaled)

# transform data 
X_train_tr_svd = my_tr_svd.transform(X_train_scaled)
X_test_tr_svd = my_tr_svd.transform(X_test_scaled)

# %%
expl_var_svd = my_tr_svd.explained_variance_ratio_
cumulative_sum_svd = np.cumsum(expl_var_svd)
cumsum_range_svd = np.arange(0, len(cumulative_sum_svd))

# Plot out the cumulative sum graph

plt.figure()
plt.plot(cumsum_range, cumulative_sum, marker='.')
plt.plot(cumsum_range_svd, cumulative_sum_svd, marker='.', color='red')
plt.axhline(0.9, c='r', linestyle='--')
plt.xlabel('Number of PCs')
plt.ylabel('Cumulative Sum of Explained Variance')

plt.show()

# %% [markdown]
# The two techniques look almost identical, let's explore further the difference in result

# %%
expl_var_svd
# Out:
# array([1.42778071e-01, 6.38263685e-02, 5.42247926e-02, 5.08596637e-02,
#        3.41743720e-02, 3.27877500e-02, 3.21941849e-02, 2.97511695e-02,
#        2.48378100e-02, 2.21380208e-02, 2.08067137e-02, 1.93557653e-02,
#        1.88578898e-02, 1.81974386e-02, 1.77845487e-02, 1.75509224e-02,
#        1.73189323e-02, 1.72900437e-02, 1.72346336e-02, 1.69303389e-02,
#        1.68808548e-02, 1.67164173e-02, 1.66318072e-02, 1.66137625e-02,
#        1.64605947e-02, 1.64006764e-02, 1.63933958e-02, 1.63925176e-02,
#        1.63890596e-02, 1.63847938e-02, 1.61637860e-02, 1.57310329e-02,
#        1.56768955e-02, 1.54436989e-02, 1.50538352e-02, 1.34290718e-02,
#        1.16682618e-02, 9.88106748e-03, 9.14950655e-03, 8.58174021e-03,
#        7.82094474e-03, 5.84501747e-03, 5.22297762e-03, 3.99846709e-03,
#        3.33576905e-03, 2.76285846e-03, 2.11717524e-03, 1.41285565e-03,
#        1.35522521e-03, 5.20052013e-04, 2.79630065e-04, 2.45283364e-04,
#        1.08336819e-04, 3.12453097e-05, 1.14859471e-06, 8.06697203e-07,
#        1.19921054e-32, 1.62212780e-32, 8.49458469e-33, 1.06872643e-32,
#        5.03049336e-33, 7.38953136e-33, 4.90023664e-33, 6.42479295e-33])

# %%
expl_var
# Out:
# array([1.42778071e-01, 6.38263685e-02, 5.42247926e-02, 5.08596637e-02,
#        3.41743720e-02, 3.27877500e-02, 3.21941849e-02, 2.97511695e-02,
#        2.48378100e-02, 2.21380208e-02, 2.08067137e-02, 1.93557653e-02,
#        1.88578898e-02, 1.81974386e-02, 1.77845487e-02, 1.75509224e-02,
#        1.73189323e-02, 1.72900437e-02, 1.72346336e-02, 1.69303389e-02,
#        1.68808548e-02, 1.67164173e-02, 1.66318072e-02, 1.66137625e-02,
#        1.64605947e-02, 1.64006764e-02, 1.63933958e-02, 1.63925176e-02,
#        1.63890596e-02, 1.63847938e-02, 1.61637860e-02, 1.57310329e-02,
#        1.56768955e-02, 1.54436989e-02, 1.50538352e-02, 1.34290718e-02,
#        1.16682618e-02, 9.88106748e-03, 9.14950655e-03, 8.58174021e-03,
#        7.82094474e-03, 5.84501747e-03, 5.22297762e-03, 3.99846709e-03,
#        3.33576905e-03, 2.76285846e-03, 2.11717524e-03, 1.41285565e-03,
#        1.35522521e-03, 5.20052013e-04, 2.79630065e-04, 2.45283364e-04,
#        1.08336819e-04, 3.12453097e-05, 1.14859471e-06, 8.06697203e-07,
#        3.79115633e-32, 9.19615224e-33, 3.70118003e-33, 1.12824858e-33,
#        1.12824858e-33, 1.12824858e-33, 1.12824858e-33, 7.73671585e-34])

# %% [markdown]
# Let's set another PCA and another druncated svd to see how they compare

# %%
my_PCA = PCA(n_components=0.8)
my_PCA.fit(X_train_scaled)

# transform data 
X_train_PCA = my_PCA.transform(X_train_scaled)
X_test_PCA = my_PCA.transform(X_test_scaled)

# %%
len(my_PCA.explained_variance_ratio_)
# Out:
# 28

# %%
my_tr_svd = TruncatedSVD(n_components=28)
my_tr_svd.fit(X_train_scaled)

# transform data 
X_train_tr_svd = my_tr_svd.transform(X_train_scaled)
X_test_tr_svd = my_tr_svd.transform(X_test_scaled)

# %%
(my_PCA.explained_variance_ratio_ - my_tr_svd.explained_variance_ratio_)
# Out:
# array([5.46784840e-15, 2.67802447e-12, 1.41934520e-11, 4.82478224e-11,
#        4.54661489e-09, 2.02902338e-09, 2.95960662e-09, 1.64611935e-09,
#        1.17899031e-07, 3.63378686e-07, 7.21702915e-08, 3.60797926e-07,
#        5.70622357e-08, 5.58300569e-06, 5.93225526e-07, 5.48914998e-06,
#        2.66445574e-06, 3.08956774e-06, 4.28436460e-06, 1.30986966e-05,
#        4.80058861e-06, 4.46053991e-06, 4.15907925e-06, 7.85385493e-06,
#        1.47674885e-06, 5.93502938e-06, 1.27358620e-06, 7.19486507e-06])

# %% [markdown]
# From these checks we can see that there is no substantial difference.
#
# Conclusion: the two decomposition techniques showed us that:
#
# - Dropping around 30 features will likely have little to no effect on our models
# - Dropping around 40 will still let us retain 80% of the variance
# - Any more dropping will probably impact  our models

# %% [markdown]
# For future sprints: we can actually drop the last components (they don't add anything).

# %% [markdown]
# ## Experiment 3
#
# How will a simple model without any PCA perform, and without treating class imbalance will work out?
#
# Let's find out with a Linear Regression with arbitrary C.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


X = df_numerical.drop(columns=['label_red_bin'])

y = df_numerical['label_red_bin']

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=33, test_size=0.3)

scaler = StandardScaler().fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression


acc_test = []
acc_train = []

c_range = [1]

for c in c_range:
    logreg = LogisticRegression(C=c, solver='saga', max_iter=1000, n_jobs=-1, verbose=2)
    logreg_fit = logreg.fit(X_train_scaled,y_train)
    acc_train.append(logreg_fit.score(X_train_scaled, y_train))
    acc_test.append(logreg_fit.score(X_test_scaled,y_test))
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# max_iter reached after 1212 seconds
# c:\Users\dfuma\anaconda3\envs\cybersec\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed: 20.2min finished

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Get class predictions
y_pred = logreg_fit.predict(X_test_scaled)

# Generate confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

# label rows and columns
cf_df = pd.DataFrame(
    cf_matrix, 
    columns=["Predicted Non-attack", "Predicted Attack"],
    index=["True Non-attack", "True Attack"]
)

display(cf_df)
# Out:
#                  Predicted Non-attack  Predicted Attack
# True Non-attack                319307             10057
# True Attack                     42477             63986

# %%
ConfusionMatrixDisplay.from_estimator(logreg_fit, X_test_scaled, y_test)

# %%
from sklearn.metrics import classification_report

report_initial = classification_report(y_test, y_pred)
print(report_initial)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92    329364
#            1       0.86      0.60      0.71    106463
#
#     accuracy                           0.88    435827
#    macro avg       0.87      0.79      0.82    435827
# weighted avg       0.88      0.88      0.87    435827

# %%
import pickle
import sys


model_info = {
    'model': logreg_fit,
    'python_version': sys.version
}

with open('model_with_version.pkl', 'wb') as file:
    pickle.dump(model_info, file)

#TODO CHANGE MODEL FILE NAME

# %% [markdown]
# So our logistic regression was both long to run (about 500 minutes) and with a really bad Recall.
#
# I'm saving the model and move on.
#
# **Conclusion**: we need either to change model parameters, change the model itself or change our approach to class imbalance.

# %% [markdown]
# ### Experiment 4 : "problems with the curve"?
#
# Maybe our linear model just fails to understand patterns on the data. Let's just check this by fitting an SVM with kernel set as rbf.

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

'''

# Define the pipeline
pipeline_svc_rbf = Pipeline([
    ('scaler', StandardScaler()),           # Scale the data
    ('svc', SVC(kernel='rbf', C=1, gamma='scale'))  # SVC with RBF kernel
])

# Fit the model on your training data
pipeline_svc_rbf.fit(X_train, y_train)


y_pred = pipeline_svc_rbf.predict(X_test)

# 
# from sklearn.metrics import accuracy_score, classification_report
# print(accuracy_score(y_test, y_pred))
# print(classification_report(y_test, y_pred))

# EXECUTION TIME 700 minutes

'''
# Out:
# "\n\n# Define the pipeline\npipeline_svc_rbf = Pipeline([\n    ('scaler', StandardScaler()),           # Scale the data\n    ('svc', SVC(kernel='rbf', C=1, gamma='scale'))  # SVC with RBF kernel\n])\n\n# Fit the model on your training data\npipeline_svc_rbf.fit(X_train, y_train)\n\n\ny_pred = pipeline_svc_rbf.predict(X_test)\n\n# For evaluation, you can use metrics like accuracy, precision, recall, etc.\n# from sklearn.metrics import accuracy_score, classification_report\n# print(accuracy_score(y_test, y_pred))\n# print(classification_report(y_test, y_pred))\n\n# EXECUTION TIME 700 minutes\n\n"

# %%
model_info_svc_rbf = {
    'model': pipeline_svc_rbf,
    'python_version': sys.version
}

with open('svc_rbf_with_version.pkl', 'wb') as file:
    pickle.dump(model_info_svc_rbf, file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 2
#       1 model_info_svc_rbf = {
# ----> 2     'model': pipeline_svc_rbf,
#       3     'python_version': sys.version
#       4 }
#       6 with open('svc_rbf_with_version.pkl', 'wb') as file:
#       7     pickle.dump(model_info_svc_rbf, file)
#
# NameError: name 'pipeline_svc_rbf' is not defined

# %%
# Load the model from the file
with open('svc_rbf_with_version.pkl', 'rb') as file:
    model_info_svc_rbf = pickle.load(file)

# Ensure that the Python version is compatible
import sys
if model_info_svc_rbf['python_version'] != sys.version:
    print("Warning: the model was saved with Python version", model_info_svc_rbf['python_version'], 
          "but you're loading with Python version", sys.version)

# Extract the model from the loaded model_info_svc_rbf
loaded_model = model_info_svc_rbf['model']

# Evaluate the model on test data
y_pred = loaded_model.predict(X_test_tr_svd)

# Generate a classification report
report = classification_report(y_test, y_pred)
print(report)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[50], line 2
#       1 # Load the model from the file
# ----> 2 with open('svc_rbf_with_version.pkl', 'rb') as file:
#       3     model_info_svc_rbf = pickle.load(file)
#       5 # Ensure that the Python version is compatible
#
# File c:\Users\dfuma\anaconda3\envs\cybersec\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'svc_rbf_with_version.pkl'

# %% [markdown]
# The output of this model is a 700 minute job with identical performance to our logistic regression. From this perspective at least adding complexity of the model without reworking the data simply doesn't work.

# %% [markdown]
# ### Experiment 5: Reworking the data
#
# Our previous experiment leads us to believe we should try a different approach: the model needs to be more "sensible" to the attack data.
#
# To do so we'll employ a SMOTE combined with Random Undersampling.
#
# Why? Because here we want to achieve two outcomes: rebalance the data while keeping its size somewhat manageble.

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as imbpipeline
from sklearn.decomposition import TruncatedSVD
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

# Create a pipeline that resamples the data, then applies scaling, dimensionality reduction, and fits a logistic regression model
pipeline_logreg2 = imbpipeline(steps=[
    ('smote', SMOTE(sampling_strategy=0.5)),
    ('under', RandomUnderSampler(sampling_strategy=0.8)),
    ('scaler', StandardScaler()),
    ('svd', TruncatedSVD(n_components=30)),
    ('logistic_regression', LogisticRegression(C=1, n_jobs=-1, verbose=2))
])

# Fit the pipeline on the training data
pipeline_logreg2.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    9.5s finished
# Pipeline(steps=[('smote', SMOTE(sampling_strategy=0.5)),
#                 ('under', RandomUnderSampler(sampling_strategy=0.8)),
#                 ('scaler', StandardScaler()),
#                 ('svd', TruncatedSVD(n_components=30)),
#                 ('logistic_regression',
#                  LogisticRegression(C=1, n_jobs=-1, verbose=2))])

# %%
from sklearn.metrics import accuracy_score

# Evaluate on training data
train_predictions = pipeline_logreg2.predict(X_train)
train_accuracy = accuracy_score(y_train, train_predictions)

# Evaluate on test data
test_predictions = pipeline_logreg2.predict(X_test)
test_accuracy = accuracy_score(y_test, test_predictions)

print(f"Training Accuracy: {train_accuracy}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Training Accuracy: 0.8183784889392366
# Test Accuracy: 0.8201144031920923

# %%
from sklearn.metrics import classification_report

report_initial = classification_report(y_test, test_predictions)
print(report_initial)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88    329364
#            1       0.61      0.71      0.66    106463
#
#     accuracy                           0.82    435827
#    macro avg       0.76      0.78      0.77    435827
# weighted avg       0.83      0.82      0.82    435827

# %% [markdown]
# The model generalizes quite well and we see improvements in the scores.
#
# But there's another transformation that could impact the performance of regression models: the distribution of the features.
#
# In a separate notebook I anlysed I which features could be log transofrm. and re-run the logistic regression.
#
# I will do this as a transoformation step of the pipeline.

# %%
from scipy import stats
import matplotlib.pyplot as plt


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply Truncated SVD
svd = TruncatedSVD(n_components=30)
X_reduced = svd.fit_transform(X_scaled)

# Now, create QQ plots for each component
for i in range(X_reduced.shape[1]):
    plt.figure()
    stats.probplot(X_reduced[:, i], dist="norm", plot=plt)
    plt.title(f'QQ Plot of Component {i+1}')
    plt.show()

del X_scaled

# %%
columns_to_log_transform= ['header_length', 'rst_count', 'tot_sum', 'magnitude', 'radius', 'covariance', 'std', 'tot_size', 'ack_count', 'urg_count', 'max', 'min']

# %%
for c in columns_to_log_transform:
    if c in X_test.columns:
        print(str(c) + ' ' + str(True))
    else:
        print(str(c) + ' ' + str(False))
# Out:
# header_length True
# rst_count True
# tot_sum True
# magnitude True
# radius True
# covariance True
# std True
# tot_size True
# ack_count True
# urg_count True
# max True
# min True

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as imbpipeline
from sklearn.decomposition import TruncatedSVD
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# Define the log transformation function, adding 1 to avoid taking log of zero
def log_transform(x):
    return np.log(x + 1)

# Create the FunctionTransformer for the log transformation
log_transformer = FunctionTransformer(log_transform)




# Define the column transformer to apply log transformation only to the specified columns
preprocessor = ColumnTransformer(
    transformers=[
        ('log', log_transformer, columns_to_log_transform)
    ],
    remainder='passthrough'  # Keep the other columns unchanged
)

# Create the pipeline
pipeline_logreg_log_transoformed = imbpipeline(steps=[
    ('smote', SMOTE(sampling_strategy=0.5)),
    ('under', RandomUnderSampler(sampling_strategy=0.8)),
    ('preprocessor', preprocessor),  # Add the preprocessor before scaling
    ('scaler', StandardScaler()),
    ('svd', TruncatedSVD(n_components=30)),
    ('logistic_regression', LogisticRegression(C=1, n_jobs=-1, verbose=2))
], verbose=True)


# Fit the pipeline on the training data
pipeline_logreg_log_transoformed.fit(X_train, y_train)
# Out:
# [Pipeline] ............. (step 1 of 6) Processing smote, total= 2.8min
# [Pipeline] ............. (step 2 of 6) Processing under, total=   1.0s
# [Pipeline] ...... (step 3 of 6) Processing preprocessor, total=   0.5s
# [Pipeline] ............ (step 4 of 6) Processing scaler, total=   0.8s
# [Pipeline] ............... (step 5 of 6) Processing svd, total=   6.7s
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    8.2s finished
# [Pipeline]  (step 6 of 6) Processing logistic_regression, total=   8.7s
# Pipeline(steps=[('smote', SMOTE(sampling_strategy=0.5)),
#                 ('under', RandomUnderSampler(sampling_strategy=0.8)),
#                 ('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('log',
#                                                   FunctionTransformer(func=<function log_transform at 0x0000014E0CBD6700>),
#                                                   ['header_length', 'rst_count',
#                                                    'tot_sum', 'magnitude',
#                                                    'radius', 'covariance',
#                                                    'std', 'tot_size',
#                                                    'ack_count', 'urg_count',
#                                                    'max', 'min'])])),
#                 ('scaler', StandardScaler()),
#                 ('svd', TruncatedSVD(n_components=30)),
#                 ('logistic_regression',
#                  LogisticRegression(C=1, n_jobs=-1, verbose=2))],
#          verbose=True)

# %%
# Predict the outcomes on the test set
y_pred = pipeline_logreg_log_transoformed.predict(X_test)

# Generate the classification report
report = classification_report(y_test, y_pred)

# Print the classification report
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90    329364
#            1       0.69      0.74      0.71    106463
#
#     accuracy                           0.85    435827
#    macro avg       0.80      0.81      0.81    435827
# weighted avg       0.86      0.85      0.86    435827

# %% [markdown]
# The log-transformation was impacting positively! We had better scores all across the classification report. Let's try out another kind of model, SVC.

# %%
from sklearn.svm import LinearSVC

# Define the Linear SVC model
linear_svc = LinearSVC(dual=False, C=1, verbose=2)  

# Include it in the same pipeline as before
pipeline_linear_svc = imbpipeline(steps=[
    ('smote', SMOTE(sampling_strategy=0.5)),
    ('under', RandomUnderSampler(sampling_strategy=0.8)),
    ('preprocessor', preprocessor),
    ('scaler', StandardScaler()),
    ('svd', TruncatedSVD(n_components=30)),
    ('linear_svc', linear_svc)
])

# Fit the pipeline on the training data
pipeline_linear_svc.fit(X_train, y_train)

# Predict and evaluate
y_pred = pipeline_linear_svc.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
# [LibLinear]              precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89    329364
#            1       0.65      0.72      0.68    106463
#
#     accuracy                           0.83    435827
#    macro avg       0.78      0.80      0.78    435827
# weighted avg       0.84      0.83      0.84    435827

# %% [markdown]
# Similar results as our logistic regression. Not much changed. This is not surprising as distance bsed models are more sensible to scaling preprocessing.
#
# So far we've dealt with regression based classifiers, distance based classifiers, now we can turn to threshold based classifiers.

# %%
del X_reduced
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 del X_reduced
#
# NameError: name 'X_reduced' is not defined

# %%
from sklearn.tree import DecisionTreeClassifier



pipe_tree = imbpipeline(steps=[
    ('smote', SMOTE(sampling_strategy=0.5)),
    ('under', RandomUnderSampler(sampling_strategy=0.8)),
    ('scaler', StandardScaler()),
    ('svd', TruncatedSVD(n_components=30)),
    ('decision_tree', DecisionTreeClassifier()) # 'decision_tree__max_depth': 30, 'decision_tree__min_samples_leaf': 4, 'decision_tree__min_samples_split': 5}
])

# Fit the pipeline on the training data
pipeline_tree = pipe_tree.fit(X_train, y_train)

# Predict the outcomes on the test set
y_pred = pipeline_tree.predict(X_test)

# Generate the classification report
from sklearn.metrics import classification_report
report_tree = classification_report(y_test, y_pred)



# Print the classification report
print(report_tree)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89    329364
#            1       0.63      0.76      0.69    106463
#
#     accuracy                           0.83    435827
#    macro avg       0.77      0.81      0.79    435827
# weighted avg       0.85      0.83      0.84    435827

# %% [markdown]
# And we have a clear accelleration vs the previous models. But we know: trees can overfit. Let's just check that.

# %%
tree_score_train = pipeline_tree.score(X_train, y_train)
tree_score_test = pipeline_tree.score(X_test, y_test)

print(f'Train score is {tree_score_train}, while test score is {tree_score_test}')
# Out:
# Train score is 0.9588486107177696, while test score is 0.8332664107547261

# %% [markdown]
# It seems a tolerable amount of overfitting but it can definetly be improved. Let's plot ROC curve alongside AUC score.

# %%
y_proba_tree = pipeline_tree.predict_proba(X_test)[:,1]

# %%
from sklearn.metrics import roc_curve, roc_auc_score


fprs, tprs, thresholds = roc_curve(y_test, y_proba_tree)
roc_auc = roc_auc_score(y_test, y_proba_tree)

plt.figure()
plt.plot(fprs, tprs, color='darkorange',
         lw=2, label='AUC = %0.2f' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('ROC Curve for ReconAttack - Decision Tree')
plt.legend(loc="best")
plt.show()

print(f'Area under curve (AUC):{roc_auc}')
print()
# Out:
# Area under curve (AUC):0.8522312440280821

# %% [markdown]
# This is an interesting result. However we are indeed still reducing the dimensionality. Maybe that's a concern for a model that essentially works on thresholds.  In networking data we have seen a lot of peaks in the distributions. Maybe that information is diluted in the Truncated SVD step and maybe that's something we don't want to loose!

# %%
from sklearn.tree import DecisionTreeClassifier



pipe_tree_no_svd = imbpipeline(steps=[
    ('smote', SMOTE(sampling_strategy=0.5)),
    ('under', RandomUnderSampler(sampling_strategy=0.8)),
    ('scaler', StandardScaler()),

    ('decision_tree', DecisionTreeClassifier())
])

# Fit the pipeline on the training data
pipeline_tree_no_svd = pipe_tree_no_svd.fit(X_train, y_train)

# Predict the outcomes on the test set
y_pred = pipeline_tree_no_svd.predict(X_test)

# Generate the classification report
from sklearn.metrics import classification_report
report_tree_no_svd = classification_report(y_test, y_pred)

# 'decision_tree__max_depth': 30, 'decision_tree__min_samples_leaf': 4, 'decision_tree__min_samples_split': 5}

# Print the classification report
print(report_tree_no_svd)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96    329364
#            1       0.85      0.91      0.88    106463
#
#     accuracy                           0.94    435827
#    macro avg       0.91      0.93      0.92    435827
# weighted avg       0.94      0.94      0.94    435827

# %% [markdown]
# WOW, such a difference in results. Let's see if it overfits.

# %%
y_pred_train = pipeline_tree_no_svd.predict(X_train)

# Generate the classification report
from sklearn.metrics import classification_report
report_tree_no_svd_train = classification_report(y_train, y_pred_train)

# %%
print(report_tree_no_svd_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    768831
#            1       0.94      1.00      0.97    248097
#
#     accuracy                           0.99   1016928
#    macro avg       0.97      0.99      0.98   1016928
# weighted avg       0.99      0.99      0.99   1016928

# %% [markdown]
# As expected the tree albeit performed generally well it does overfit quite a lot. We need to apply other techniques such pruning and tuning the hyperparameters.
#
# Before doing that, let's take a look at the features' importance

# %%
tree_no_svd = pipeline_tree_no_svd.named_steps['decision_tree']

feature_importances = tree_no_svd.feature_importances_

sorted_indices = np.argsort(feature_importances)[::-1]

# Step 3: Calculate the cumulative sum of the sorted feature importances
cumulative_importances = np.cumsum(feature_importances[sorted_indices])

plt.figure(figsize=(10, 6))
plt.plot(cumulative_importances, marker='o', linestyle='-')
plt.xlabel('Number of Features')
plt.ylabel('Cumulative Importance')
plt.title('Cumulative Sum of Feature Importances')
plt.grid(True)
plt.show()

# %% [markdown]
# We can clearly see that our Tree did very well mainly due to 30 features let's see what they are.

# %%
feature_names = X.columns

# Map sorted indices to sorted feature names
sorted_feature_names = [feature_names[i] for i in sorted_indices]

# Print the most important features
print("Most important features in descending order of importance:")
for name in sorted_feature_names:
    print(name)
# Out:
# Most important features in descending order of importance:
# header_length
# iat
# flow_duration
# syn_count
# https
# tot_size
# urg_count
# rst_count
# duration
# srate
# rate
# ack_count
# min
# tot_sum
# covariance
# rst_flag_number
# max
# variance
# avg
# std
# magnitude
# radius
# magnitue
# udp
# protocol_type_BBN-RCC-MON
# protocol_type_IGP
# protocol_type_NVP-II
# protocol_type_EGP
# ack_flag_number
# protocol_type_CBT
# protocol_type_TCP
# tcp
# protocol_type_ST
# number
# http
# fin_count
# protocol_type_IPv4
# llc
# psh_flag_number
# protocol_type_PUP
# protocol_type_ARGUS (deprecated)
# protocol_type_EMCON
# protocol_type_GGP
# protocol_type_XNET
# syn_flag_number
# dns
# protocol_type_UDP
# ipv
# arp
# weight
# protocol_type_ICMP
# protocol_type_HOPOPT
# drate
# fin_flag_number
# protocol_type_IGMP
# dhcp
# ece_flag_number
# irc
# protocol_type_CHAOS
# icmp
# telnet
# smtp
# ssh
# cwr_flag_number

# %% [markdown]
# Interesting results! Apparently our most important features were the size of the packet (header lenght), metrics about the duration of the flow of packets (flow_duration and iat) and number of request.
#
# #### Interpretation time!
#
# These results totally make sense if you think about how these sort of attacks are performed. They are really multiple requests for info in the network, very lightweight,  brief and frequent. It seems our tree is getting the hang out of it.

# %% [markdown]
# ## Cross Validation and Fine Tuning
#
# Now that we have a good model let's try to use GridSearchCV to limit overfitting and get better accuracy (and run cross validation at the same time).

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import make_scorer, precision_score


# Define the parameter grid to search
param_grid = {
    'decision_tree__max_depth': [10,  30, 50],
    'decision_tree__min_samples_split': [2, 5, 10],
    'decision_tree__min_samples_leaf': [1, 2, 4],
}

# Create a scorer that focuses on precision
precision_scorer = make_scorer(precision_score)

# Create a new pipeline with a decision tree and include the scaler
pipeline = imbpipeline(steps=[
    ('smote', SMOTE(sampling_strategy=0.5)),
    ('under', RandomUnderSampler(sampling_strategy=0.8)),
    ('scaler', StandardScaler()),
    ('decision_tree', DecisionTreeClassifier())
])

# Create the GridSearchCV object
grid_search = GridSearchCV(estimator=pipeline, param_grid=param_grid, scoring=precision_scorer, cv=5)

# Fit the GridSearchCV object to the training data
grid_search.fit(X_train, y_train)

# The best_estimator_ attribute will now be a pipeline with the best combination of parameters
best_model = grid_search.best_estimator_


y_pred = best_model.predict(X_test)

# Print the best combination of parameters
print("Best parameters found: ", grid_search.best_params_)
# Out:
# Best parameters found:  {'decision_tree__max_depth': 30, 'decision_tree__min_samples_leaf': 4, 'decision_tree__min_samples_split': 5}

# %%
from sklearn.tree import DecisionTreeClassifier



pipe_tree_no_svd_optimized = imbpipeline(steps=[
    ('smote', SMOTE(sampling_strategy=0.5)),
    ('under', RandomUnderSampler(sampling_strategy=0.8)),
    ('scaler', StandardScaler()),
    ('decision_tree', DecisionTreeClassifier(max_depth=30, min_samples_leaf=4, min_samples_split=5))
])

# Fit the pipeline on the training data
pipeline_tree_no_svd_optimized = pipe_tree_no_svd_optimized.fit(X_train, y_train)

# Predict the outcomes on the test set
y_pred = pipeline_tree_no_svd_optimized.predict(X_test)

# Generate the classification report
report_tree_no_svd_optimized = classification_report(y_test, y_pred)

# Print the classification report
print(report_tree_no_svd_optimized)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96    329364
#            1       0.88      0.91      0.89    106463
#
#     accuracy                           0.95    435827
#    macro avg       0.92      0.93      0.93    435827
# weighted avg       0.95      0.95      0.95    435827

# %%
best_tree_report = classification_report(y_test, y_pred)
print(best_tree_report)


y_pred_train = best_model.predict(X_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96    329364
#            1       0.88      0.91      0.89    106463
#
#     accuracy                           0.95    435827
#    macro avg       0.92      0.93      0.93    435827
# weighted avg       0.95      0.95      0.95    435827

# %% [markdown]
# Such amazing results, Let's now check if it overfits.

# %%
best_tree_report_train = classification_report(y_train, y_pred_train)
print(best_tree_report_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    768831
#            1       0.94      1.00      0.97    248097
#
#     accuracy                           0.99   1016928
#    macro avg       0.97      0.99      0.98   1016928
# weighted avg       0.99      0.99      0.99   1016928

# %% [markdown]
# Again it does slightly overfit but with a maximum gap of 9 points, it's far from problematic. Let's analyze the ROC curve and AUC score.

# %%
y_proba = best_model.predict_proba(X_test)[:,1]

fprs, tprs, thresholds = roc_curve(y_test, y_proba)
roc_auc = roc_auc_score(y_test, y_proba)

plt.figure()
plt.plot(fprs, tprs, color='darkorange',
         lw=2, label='AUC = %0.2f' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('ROC Curve for ReconAttack - Decision Tree Optimized')
plt.legend(loc="best")
plt.show()

print(f'Area under curve (AUC):{roc_auc}')
print()
# Out:
# Area under curve (AUC):0.9585123403849007

# %%
best_model
# Out:
# Pipeline(steps=[('smote', SMOTE(sampling_strategy=0.5)),
#                 ('under', RandomUnderSampler(sampling_strategy=0.8)),
#                 ('scaler', StandardScaler()),
#                 ('decision_tree',
#                  DecisionTreeClassifier(max_depth=30, min_samples_leaf=4,
#                                         min_samples_split=5))])

# %% [markdown]
# To be fair, this model seems to perform very well for our task.
# The combination of max depth = 30, min_samples_leaf = 4, min_samples_split = 5 was optimizing for precision.
#
# Vs the unoptimized version we gained 3 points in precsion while not loosing recall. Great result!

# %% [markdown]
# # Sprint 3 PREVIEW
#
# I want to check if we can apply log transformation results in better performance

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as imbpipeline
from sklearn.decomposition import TruncatedSVD
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

# Create a pipeline that resamples the data, then applies scaling, dimensionality reduction, and fits a random forest model
pipeline = imbpipeline(steps=[
    ('smote', SMOTE(sampling_strategy=0.5)),
    ('under', RandomUnderSampler(sampling_strategy=0.8)),
    ('scaler', StandardScaler()),
    
    ('random_forest', RandomForestClassifier(n_estimators=100, n_jobs=-1, verbose=2,max_depth=30, min_samples_leaf=4, min_samples_split=5))
])

# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# building tree 1 of 100building tree 2 of 100
# building tree 3 of 100
#
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# building tree 10 of 100
# building tree 11 of 100
# building tree 12 of 100
# building tree 13 of 100
# building tree 14 of 100
# building tree 15 of 100
# building tree 16 of 100
# building tree 17 of 100
# building tree 18 of 100
# building tree 19 of 100
# building tree 20 of 100
# building tree 21 of 100
# building tree 22 of 100
# building tree 23 of 100
# building tree 24 of 100
# building tree 25 of 100
# building tree 26 of 100
# building tree 27 of 100
# building tree 28 of 100
# building tree 29 of 100
# building tree 30 of 100
# building tree 31 of 100
# building tree 32 of 100
# building tree 33 of 100
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   45.8s
# building tree 34 of 100
# building tree 35 of 100
# building tree 36 of 100
# building tree 37 of 100
# building tree 38 of 100
# building tree 39 of 100
# building tree 40 of 100
# building tree 41 of 100
# building tree 42 of 100
# building tree 43 of 100
# building tree 44 of 100
# building tree 45 of 100
# building tree 46 of 100
# building tree 47 of 100
# building tree 48 of 100
# building tree 49 of 100
# building tree 50 of 100
# building tree 51 of 100
# building tree 52 of 100
# building tree 53 of 100
# building tree 54 of 100
# building tree 55 of 100
# building tree 56 of 100
# building tree 57 of 100
# building tree 58 of 100
# building tree 59 of 100
# building tree 60 of 100
# building tree 61 of 100
# building tree 62 of 100
# building tree 63 of 100
# building tree 64 of 100
# building tree 65 of 100
# building tree 66 of 100
# building tree 67 of 100
# building tree 68 of 100
# building tree 69 of 100
# building tree 70 of 100
# building tree 71 of 100
# building tree 72 of 100
# building tree 73 of 100
# building tree 74 of 100
# building tree 75 of 100
# building tree 76 of 100
# building tree 77 of 100
# building tree 78 of 100
# building tree 79 of 100
# building tree 80 of 100
# building tree 81 of 100
# building tree 82 of 100
# building tree 83 of 100
# building tree 84 of 100
# building tree 85 of 100
# building tree 86 of 100
# building tree 87 of 100
# building tree 88 of 100
# building tree 89 of 100
# building tree 90 of 100
# building tree 91 of 100
# building tree 92 of 100
# building tree 93 of 100
# building tree 94 of 100
# building tree 95 of 100
# building tree 96 of 100
# building tree 97 of 100
# building tree 98 of 100
# building tree 99 of 100
# building tree 100 of 100
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  2.5min finished
# Pipeline(steps=[('smote', SMOTE(sampling_strategy=0.5)),
#                 ('under', RandomUnderSampler(sampling_strategy=0.8)),
#                 ('scaler', StandardScaler()),
#                 ('random_forest',
#                  RandomForestClassifier(max_depth=30, min_samples_leaf=4,
#                                         min_samples_split=5, n_jobs=-1,
#                                         verbose=2))])

# %%
from sklearn.metrics import classification_report

y_pred = pipeline.predict(X_test)

report = classification_report(y_test, y_pred)
print(report)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.4s finished
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97    329364
#            1       0.91      0.92      0.91    106463
#
#     accuracy                           0.96    435827
#    macro avg       0.94      0.95      0.94    435827
# weighted avg       0.96      0.96      0.96    435827

# %% [markdown]
# This is a very accurate classifier. Let's see if it overfits.

# %%
y_pred_train = pipeline.predict(X_train)

report_train = classification_report(y_train, y_pred_train)
print(report_train)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    5.4s finished
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98    768831
#            1       0.95      0.96      0.95    248097
#
#     accuracy                           0.98   1016928
#    macro avg       0.97      0.97      0.97   1016928
# weighted avg       0.98      0.98      0.98   1016928

# %% [markdown]
# Compared to our tree this model generalizes better. Now it's time to experiment with yet another classifier: adaboost.
#
# Why adaboost? Because can use the optimized hyperparameters of the decision tree as a base learner.

# %%
from imblearn.pipeline import Pipeline as imbpipeline
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import TruncatedSVD
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report


decision_tree = DecisionTreeClassifier(
    max_depth=30, 
    min_samples_leaf=4, 
    min_samples_split=5
)

# Create an AdaBoost instance with the decision tree as the base estimator
ada_boost = AdaBoostClassifier(
    base_estimator=decision_tree,
    n_estimators=50,
    learning_rate=1.0, 
    
)

# Define pipeline with AdaBoost
pipe_ada = imbpipeline(steps=[
    ('smote', SMOTE(sampling_strategy=0.5)),
    ('under', RandomUnderSampler(sampling_strategy=0.8)),
    ('scaler', StandardScaler()),
    ('adaboost', ada_boost)], verbose=True)

# Fit the pipeline on the training data
pipeline_ada = pipe_ada.fit(X_train, y_train)

# Predict the outcomes on the test set
y_pred = pipeline_ada.predict(X_test)

# Generate the classification report
report_ada = classification_report(y_test, y_pred)


print(report_ada)
# Out:
# [Pipeline] ............. (step 1 of 4) Processing smote, total= 2.1min
# [Pipeline] ............. (step 2 of 4) Processing under, total=   0.5s
# [Pipeline] ............ (step 3 of 4) Processing scaler, total=   2.4s
# c:\Users\dfuma\anaconda3\envs\cybersec\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# [Pipeline] .......... (step 4 of 4) Processing adaboost, total=43.0min
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97    329364
#            1       0.91      0.93      0.92    106463
#
#     accuracy                           0.96    435827
#    macro avg       0.95      0.95      0.95    435827
# weighted avg       0.96      0.96      0.96    435827

# %%
from sklearn.model_selection import GridSearchCV
from imblearn.pipeline import Pipeline as imbpipeline
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier



# Define decision tree and AdaBoost as before
decision_tree = DecisionTreeClassifier(max_depth=30, min_samples_leaf=4, min_samples_split=5)
ada_boost = AdaBoostClassifier(base_estimator=decision_tree, n_estimators=50)

# Define pipeline with AdaBoost
pipe_ada = imbpipeline(steps=[
    ('smote', SMOTE(sampling_strategy=0.5)),
    ('under', RandomUnderSampler(sampling_strategy=0.8)),
    ('scaler', StandardScaler()),
    ('adaboost', ada_boost)
])

# Parameters grid to search through
params_grid = {
    'adaboost__learning_rate': [0.1, 1.0] 
}

# Set up GridSearchCV
grid_search_adaboost = GridSearchCV(pipe_ada, param_grid=params_grid, cv=5, scoring='recall', verbose=1)

# Fit GridSearchCV on the training data
grid_search_adaboost.fit(X_train, y_train)

# Best parameters and best score
print("Best parameters:", grid_search_adaboost.best_params_)
print("Best score:", grid_search_adaboost.best_score_)

# Predict the outcomes on the test set using the best found parameters
y_pred = grid_search_adaboost.predict(X_test)

# Generate the classification report
from sklearn.metrics import classification_report
report_ada = classification_report(y_test, y_pred)

# Print the classification report
print(report_ada)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# c:\Users\dfuma\anaconda3\envs\cybersec\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\dfuma\anaconda3\envs\cybersec\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\dfuma\anaconda3\envs\cybersec\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\dfuma\anaconda3\envs\cybersec\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\dfuma\anaconda3\envs\cybersec\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\dfuma\anaconda3\envs\cybersec\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\dfuma\anaconda3\envs\cybersec\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\dfuma\anaconda3\envs\cybersec\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\dfuma\anaconda3\envs\cybersec\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\dfuma\anaconda3\envs\cybersec\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\dfuma\anaconda3\envs\cybersec\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Best parameters: {'adaboost__learning_rate': 1.0}
# Best score: 0.9276855337794917
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97    329364
#            1       0.91      0.93      0.92    106463
#
#     accuracy                           0.96    435827
#    macro avg       0.95      0.95      0.95    435827
# weighted avg       0.96      0.96      0.96    435827

# %% [markdown]
# This is a really great result. Let's check if it overfits.

# %%
y_pred_train = grid_search_adaboost.predict(X_train)

report_ada_train = classification_report(y_train, y_pred_train)

print(report_ada_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    768831
#            1       0.97      1.00      0.98    248097
#
#     accuracy                           0.99   1016928
#    macro avg       0.98      0.99      0.99   1016928
# weighted avg       0.99      0.99      0.99   1016928

# %% [markdown]
# It does overfit a little more vs the random forest. However it does have higher recall. It's a really close call between the two models. I will choose adaboost as it is more promising and faster in inference process vs random forest. After all the hyperparameter tuning was very minimal and the results were comparable. With more time and resources adaboost could significantly outperform random forest in this scenario.
#
# Let's save this model and inspect it further.

# %%
import pickle


with open('pipeline_adaboost.pkl', 'wb') as file:
    pickle.dump(grid_search_adaboost, file)

# %% [markdown]
# ### Advanced Modelling, binary classification performance : Objective Achieved
#
# Leveraging on our Decision Tree Classifier we were able to Adapt it to an adaboost ensamble model which further improved our work.

# %% [markdown]
# Let's analyze the feature importance.

# %%
ada_model = grid_search_adaboost.best_estimator_.named_steps['adaboost']

feature_importances = ada_model.feature_importances_

sorted_indices = np.argsort(feature_importances)[::-1]

# Step 3: Calculate the cumulative sum of the sorted feature importances
cumulative_importances = np.cumsum(feature_importances[sorted_indices])

plt.figure(figsize=(10, 6))
plt.plot(cumulative_importances, marker='o', linestyle='-')
plt.xlabel('Number of Features')
plt.ylabel('Cumulative Importance')
plt.title('Cumulative Sum of Feature Importances')
plt.grid(True)
plt.show()

# %% [markdown]
# Similar pattern as before! Around 30 features make up for all the importance of the model. Let's see which features are the most important ones.

# %%
feature_names = X.columns

# Map sorted indices to sorted feature names
sorted_feature_names = [feature_names[i] for i in sorted_indices]

# Print the most important features
print("Most important features in descending order of importance:")
for name in sorted_feature_names:
    print(name)
# Out:
# Most important features in descending order of importance:
# header_length
# iat
# syn_count
# flow_duration
# https
# urg_count
# tot_size
# rst_count
# duration
# tot_sum
# srate
# avg
# min
# rate
# ack_count
# covariance
# max
# std
# radius
# variance
# udp
# magnitue
# magnitude
# protocol_type_TCP
# protocol_type_IGP
# protocol_type_NVP-II
# protocol_type_BBN-RCC-MON
# protocol_type_CBT
# rst_flag_number
# protocol_type_EGP
# tcp
# ack_flag_number
# protocol_type_ST
# http
# psh_flag_number
# protocol_type_IPv4
# weight
# protocol_type_PUP
# protocol_type_EMCON
# fin_count
# number
# protocol_type_ARGUS (deprecated)
# syn_flag_number
# protocol_type_XNET
# protocol_type_GGP
# dns
# ipv
# protocol_type_UDP
# llc
# arp
# protocol_type_ICMP
# protocol_type_IGMP
# protocol_type_HOPOPT
# protocol_type_CHAOS
# fin_flag_number
# dhcp
# cwr_flag_number
# ece_flag_number
# icmp
# telnet
# irc
# drate
# smtp
# ssh

# %% [markdown]
# Similarly as before the size of the packets, their duration and the number of requests done are the primary factors. Again small, numerous and short requests seem to be the greatest indicators. This is perfectly consistent with our understanding of Recon Attacks.
#
# ## CONCLUSION
#
# This modelling steps are enough to provide a very accurate binary classifier, in our case Adaboost and Random Forest performed similarly but adaboost is more promising for future applications.
#
# Since we have significantly stepped up the performance of our classifier vs the baseline models provided by CICIOT 2023 researched by applying the pledged specialization, we can say that the outcome of our work is succesful
#
# This ends Sprint 2. Our next step in Sprint 3 will be to classify the type of Recon Attack, i.e. the surface of attack.
